# %% [markdown]
# # Running This Guide:

# %% [markdown]
# This guide is presented as a series of Jupyter notebooks covering both Tensorflow and PyTorch using a Python runtime.
#
# If you would like to run this code yourself, you can do so using the following steps:

# %% [markdown]
# __Setup__:
#
# The basic prerequisites you will need to use TensorRT are:
#
# - a [supported NVIDIA GPU](https://docs.nvidia.com/deeplearning/tensorrt/support-matrix/index.html#hardware-precision-matrix) (preferred compute capability 7.0 or higher - which includes INT8 precision support)
# - latest [NVIDIA GPU drivers](https://docs.nvidia.com/datacenter/tesla/tesla-installation-notes/index.html)
# - a [supported CUDA and cuDNN](https://docs.nvidia.com/deeplearning/tensorrt/support-matrix/index.html#platform-matrix) installation
#
# You can make sure your GPU environment is properly configured and check which GPU and CUDA version you are using with nvidia-smi:

# %%
# !nvidia-smi
# Out:
# Mon Feb 17 23:50:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    On  |   00000000:01:00.0  On |                  N/A |
# | N/A   64C    P5             19W /  115W |      66MiB /   6144MiB |     30%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1842351      G   /usr/lib/xorg/Xorg                             55MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# For some of the examples you will also need pycuda, skimage, and onnx:

# %%
# !pip install pycuda onnx scikit-image
# Out:
# Requirement already satisfied: pycuda in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (2025.1)
# Requirement already satisfied: onnx in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (1.17.0)
# Collecting scikit-image
#   Downloading scikit_image-0.25.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: pytools>=2011.2 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from pycuda) (2025.1.1)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from pycuda) (4.3.6)
# Requirement already satisfied: mako in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from pycuda) (1.3.9)
# Requirement already satisfied: numpy>=1.20 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from onnx) (3.20.2)
# Requirement already satisfied: scipy>=1.11.2 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from scikit-image) (1.15.1)
# Requirement already satisfied: networkx>=3.0 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from scikit-image) (11.1.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.1.10-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: typing-extensions>=4.5 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from pytools>=2011.2->pycuda) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/peterc/miniconda3/envs/autoforge/lib/python3.11/site-packages (from mako->pycuda) (3.0.2)
# Downloading scikit_image-0.25.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 1.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading tifffile-2025.1.10-py3-none-any.whl (227 kB)
# Installing collected packages: tifffile, imageio, scikit-image
# Successfully installed imageio-2.37.0 scikit-image-0.25.1 tifffile-2025.1.10

# %% [markdown]
# __PyTorch__:

# %% [markdown]
# We will be using PyTorch to walk through the basic steps of deploying a TensorRT model by [exporting the model in ONNX format](https://pytorch.org/docs/stable/onnx.html).
#
# You can find PyTorch installation instructions [here](https://pytorch.org/get-started/locally/), or use one of NVIDIA's NGC containers [here](https://ngc.nvidia.com/catalog/containers/nvidia:pytorch).
#
# You will also need torchvision:

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %% [markdown]
# __Using Colab:__
#
# You can also test these notebooks out using [Google Colab](https://colab.research.google.com/), which includes PyTorch, as well as supported NVIDIA drivers. __Make sure to select a GPU hardware accelerator__ in the runtime options. Just note that TensorRT performance is best on newer gpus, Colab often has trouble with reduced precision inference, and you will have to use an older version of TensorRT.

# %% [markdown]
# __TensorRT Support:__
#
# TensorRT support for NVIDIA GPUs is determined by their __compute capability__. You can check the compute cabapility of your card on the [NVIDIA website](https://developer.nvidia.com/cuda-gpus).
#
# TensorRT supports different feautures depending on your compute capability. Higher compute capabilities allow additional TensorRT optimizations, like reduced precision inference. You can check which TensorRT features are supported by your compute capability in the [TensorRT documentation](https://docs.nvidia.com/deeplearning/tensorrt/support-matrix/index.html#hardware-precision-matrix).

# %% [markdown]
# __Next Steps:__
#
# Now, start by opening [1. Introduction.ipynb](./1.%20Introduction.ipynb) and proceed through the notebook!
#
# The notebooks included with this guide are:
# - [1. Introduction.ipynb](./1.%20Introduction.ipynb)
# - [2. Using PyTorch through ONNX.ipynb](./2.%20Using%20PyTorch%20through%20ONNX.ipynb)
# - [3. Understanding TensorRT Runtimes.ipynb](./3.%20Understanding%20TensorRT%20Runtimes.ipynb)
